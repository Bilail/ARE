# %%
from tkinter import *
import math,random
import time

LARGEUR = 1500
HAUTEUR = 500

# Création de la fenêtre principale
Mafenetre = Tk()
Mafenetre.title("Animation")

#photo = PhotoImage(file="./Téléchargements/route3.png")


# Création d'un widget Canvas
Canevas = Canvas(Mafenetre,height=HAUTEUR,width=LARGEUR,bg='white')
#Canevas.create_image(0, 0, anchor=NW, image=photo)
Canevas.pack(padx=5,pady=5)


# ------------position initiale au milieu
X = 200
Y = 100
X2 = 10
Y2 = 100

#-----------vitesse initial
v_limite = 6
DX = 5 # 100 pixel/seconde (10m/s ? 36 km/h ?)
DX2 = 6 # 120 pixel/seconde

#----------distance de securiter
dst_secu=50 
dst_depassement=75

#------------puissance des frein( un chiffre apres la virgule max)
Power_Frein=1


ligne = Canevas.create_line(0,Y+25,LARGEUR,Y+25)
ligne2 = Canevas.create_line(0,Y-5,LARGEUR,Y-5,stipple='gray75')
ligne3 = Canevas.create_line(0,Y-35,LARGEUR,Y-35)

def randomcouleur():
    couleurde = random.randint(1,370)
    colo = ['gainsboro', 'floral white', 'old lace',
    'linen', 'antique white', 'papaya whip', 'blanched almond', 'bisque', 'peach puff',
    'navajo white', 'lemon chiffon', 'mint cream', 'alice blue', 'lavender',
    'lavender blush', 'misty rose', 'dark slate gray', 'dim gray', 'slate gray',
    'light slate gray', 'gray', 'light grey', 'midnight blue', 'navy', 'cornflower blue', 'dark slate blue',
    'slate blue', 'medium slate blue', 'light slate blue', 'medium blue', 'royal blue',  'blue',
    'dodger blue', 'deep sky blue', 'sky blue', 'light sky blue', 'steel blue', 'light steel blue',
    'light blue', 'powder blue', 'pale turquoise', 'dark turquoise', 'medium turquoise', 'turquoise',
    'cyan', 'light cyan', 'cadet blue', 'medium aquamarine', 'aquamarine', 'dark green', 'dark olive green',
    'dark sea green', 'sea green', 'medium sea green', 'light sea green', 'pale green', 'spring green',
    'lawn green', 'medium spring green', 'green yellow', 'lime green', 'yellow green',
    'forest green', 'olive drab', 'dark khaki', 'khaki', 'pale goldenrod', 'light goldenrod yellow',
    'light yellow', 'yellow', 'gold', 'light goldenrod', 'goldenrod', 'dark goldenrod', 'rosy brown',
    'indian red', 'saddle brown', 'sandy brown',
    'dark salmon', 'salmon', 'light salmon', 'orange', 'dark orange',
    'coral', 'light coral', 'tomato', 'orange red', 'hot pink', 'deep pink', 'pink', 'light pink',
    'pale violet red', 'maroon', 'medium violet red', 'violet red',
    'medium orchid', 'dark orchid', 'dark violet', 'blue violet', 'purple', 'medium purple',
    'thistle', 'snow2', 'snow3',
    'snow4', 'seashell2', 'seashell3', 'seashell4', 'AntiqueWhite1', 'AntiqueWhite2',
    'AntiqueWhite3', 'AntiqueWhite4', 'bisque2', 'bisque3', 'bisque4', 'PeachPuff2',
    'PeachPuff3', 'PeachPuff4', 'NavajoWhite2', 'NavajoWhite3', 'NavajoWhite4',
    'LemonChiffon2', 'LemonChiffon3', 'LemonChiffon4', 'cornsilk2', 'cornsilk3',
    'cornsilk4', 'ivory2', 'ivory3', 'ivory4', 'honeydew2', 'honeydew3', 'honeydew4',
    'LavenderBlush2', 'LavenderBlush3', 'LavenderBlush4', 'MistyRose2', 'MistyRose3',
    'MistyRose4', 'azure2', 'azure3', 'azure4', 'SlateBlue1', 'SlateBlue2', 'SlateBlue3',
    'SlateBlue4', 'RoyalBlue1', 'RoyalBlue2', 'RoyalBlue3', 'RoyalBlue4', 'blue2', 'blue4',
    'DodgerBlue2', 'DodgerBlue3', 'DodgerBlue4', 'SteelBlue1', 'SteelBlue2',
    'SteelBlue3', 'SteelBlue4', 'DeepSkyBlue2', 'DeepSkyBlue3', 'DeepSkyBlue4',
    'SkyBlue1', 'SkyBlue2', 'SkyBlue3', 'SkyBlue4', 'LightSkyBlue1', 'LightSkyBlue2',
    'LightSkyBlue3', 'LightSkyBlue4', 'SlateGray1', 'SlateGray2', 'SlateGray3',
    'SlateGray4', 'LightSteelBlue1', 'LightSteelBlue2', 'LightSteelBlue3',
    'LightSteelBlue4', 'LightBlue1', 'LightBlue2', 'LightBlue3', 'LightBlue4',
    'LightCyan2', 'LightCyan3', 'LightCyan4', 'PaleTurquoise1', 'PaleTurquoise2',
    'PaleTurquoise3', 'PaleTurquoise4', 'CadetBlue1', 'CadetBlue2', 'CadetBlue3',
    'CadetBlue4', 'turquoise1', 'turquoise2', 'turquoise3', 'turquoise4', 'cyan2', 'cyan3',
    'cyan4', 'DarkSlateGray1', 'DarkSlateGray2', 'DarkSlateGray3', 'DarkSlateGray4',
    'aquamarine2', 'aquamarine4', 'DarkSeaGreen1', 'DarkSeaGreen2', 'DarkSeaGreen3',
    'DarkSeaGreen4', 'SeaGreen1', 'SeaGreen2', 'SeaGreen3', 'PaleGreen1', 'PaleGreen2',
    'PaleGreen3', 'PaleGreen4', 'SpringGreen2', 'SpringGreen3', 'SpringGreen4',
    'green2', 'green3', 'green4', 'chartreuse2', 'chartreuse3', 'chartreuse4',
    'OliveDrab1', 'OliveDrab2', 'OliveDrab4', 'DarkOliveGreen1', 'DarkOliveGreen2',
    'DarkOliveGreen3', 'DarkOliveGreen4', 'khaki1', 'khaki2', 'khaki3', 'khaki4',
    'LightGoldenrod1', 'LightGoldenrod2', 'LightGoldenrod3', 'LightGoldenrod4',
    'LightYellow2', 'LightYellow3', 'LightYellow4', 'yellow2', 'yellow3', 'yellow4',
    'gold2', 'gold3', 'gold4', 'goldenrod1', 'goldenrod2', 'goldenrod3', 'goldenrod4',
    'DarkGoldenrod1', 'DarkGoldenrod2', 'DarkGoldenrod3', 'DarkGoldenrod4',
    'RosyBrown1', 'RosyBrown2', 'RosyBrown3', 'RosyBrown4', 'IndianRed1', 'IndianRed2',
    'IndianRed3', 'IndianRed4', 'sienna1', 'sienna2', 'sienna3', 'sienna4', 'burlywood1',
    'burlywood2', 'burlywood3', 'burlywood4', 'wheat1', 'wheat2', 'wheat3', 'wheat4', 'tan1',
    'tan2', 'tan4', 'chocolate1', 'chocolate2', 'chocolate3', 'firebrick1', 'firebrick2',
    'firebrick3', 'firebrick4', 'brown1', 'brown2', 'brown3', 'brown4', 'salmon1', 'salmon2',
    'salmon3', 'salmon4', 'LightSalmon2', 'LightSalmon3', 'LightSalmon4', 'orange2',
    'orange3', 'orange4', 'DarkOrange1', 'DarkOrange2', 'DarkOrange3', 'DarkOrange4',
    'coral1', 'coral2', 'coral3', 'coral4', 'tomato2', 'tomato3', 'tomato4', 'OrangeRed2',
    'OrangeRed3', 'OrangeRed4', 'red2', 'red3', 'red4', 'DeepPink2', 'DeepPink3', 'DeepPink4',
    'HotPink1', 'HotPink2', 'HotPink3', 'HotPink4', 'pink1', 'pink2', 'pink3', 'pink4',
    'LightPink1', 'LightPink2', 'LightPink3', 'LightPink4', 'PaleVioletRed1',
    'PaleVioletRed2', 'PaleVioletRed3', 'PaleVioletRed4', 'maroon1', 'maroon2',
    'maroon3', 'maroon4', 'VioletRed1', 'VioletRed2', 'VioletRed3', 'VioletRed4',
    'magenta2', 'magenta3', 'magenta4', 'orchid1', 'orchid2', 'orchid3', 'orchid4', 'plum1',
    'plum2', 'plum3', 'plum4', 'MediumOrchid1', 'MediumOrchid2', 'MediumOrchid3',
    'MediumOrchid4', 'DarkOrchid1', 'DarkOrchid2', 'DarkOrchid3', 'DarkOrchid4',
    'purple1', 'purple2', 'purple3', 'purple4', 'MediumPurple1', 'MediumPurple2',
    'MediumPurple3', 'MediumPurple4', 'thistle1', 'thistle2', 'thistle3', 'thistle4']
    
    return colo[couleurde]
    
    
    
#-------------- la forme
listecoor = []
D = []
vtsdepart = 4
def lescoor(nombrevoiture):
    global listecoor, D
    
    for i in range(nombrevoiture):
        xx = 100 +i*85
        yy = 100 
        listecoor.append((xx,yy))
    
    for j in range(nombrevoiture):
        D.append(vtsdepart)
    
def lesvoitures():
    global listecoor, D
    listevoiture = []
    for i in range(len(listecoor)):
        x,y = listecoor[i]
        i=Canevas.create_rectangle(x,y,x+30,y+20,width=1,fill='blue')    
    
    
lescoor(6)    
lesvoitures()

def tourdepiste():
    global listecoor, D
    
    for i in range(len(listecoor)):
        x,y = listecoor[i]
    
        if x > LARGEUR:
            x = -30

        listecoor[i]=x+D[i],y




def distancedesecu():
    global X,Y,DX,Bouton1,X2,DX2,dst_secu,Power_Frein,Y2,listecoor, D
    for i in range(len(listecoor)):
        xi,yi = listecoor[i]
        b=True
        for j in range(len(listecoor)):
            if i!=j:
                xj,yj = listecoor[j]
                if ((xj-xi)<=80 and (xj-xi)>0) and yi==yj :#yi <= yj and yi >= yj-20:
                    b=False
                    break
        if b:
            if D[i] <= 4:
                D[i] = 4
        else:
            if D[i]-Power_Frein >=0 :
                D[i]=D[i]-Power_Frein
    return
    

def depassement():
    global X,Y,DX,X2,DX2,dst_secu,Y2,listecoor, D
    for i in range(len(listecoor)):
        xi,yi = listecoor[i]
        b=True
        for j in range(len(listecoor)):
            if i!=j:
                xj,yj = listecoor[j]
                if (xj-xi)<=80 and (xj-xi)>0 and yi==yj:#yi <= yj and yi >= yj-20:
                    b=False
                    #break
                    
        if b==False:
            #if (xj-xi)<=80 and (xj-xi)>80:
            listecoor[i]= xi,yi-30
            #if yi <= 100 :
             #   listecoor[i]= xi,(yi+5)
        if b:
            if (xj-xi)<-80 and (xj-xi)>-60 and yi+30 <=100:
                listecoor[i]= xi,yi+30
"""""          
        for i in range(len(listecoor)):
            xi,yi = listecoor[i]
            b=True
            for j in range(len(listecoor)):
                if i!=j:
                    xj,yj = listecoor[j]
                    if (xj-xi)>=-80 and yi==70:#yi <= yj and yi >= yj-20:
                        b=False
                        #break
                    
        if b==False:
            #if (xj-xi)<=80 and (xj-xi)>80:
            listecoor[i]= xi,yi+30
            #if yi <= 100 :
             #   listecoor[i]= xi,(yi+5)
"""""
   
    
"""""
    if X - (X2+30) <=dst_depassement and X - (X2+30) >= 0 and Y2 <= Y and Y2+25 >= Y:
        Y2 = Y2 - 5 
    elif X2-(X+30)  >=dst_secu and Y2 <= Y-5:
        Y2 = Y2 + 5 
"""""

def accident():
    global X,Y,DX,Bouton1,X2,DX2,dst_secu,Power_Frein,Y2
    
#accident(rencontre entre deux voiture)
    if X - (X2+30) <=0 and X - (X2+30) >= -20 and Y2 <= Y+20 and Y2+20 >= Y:#depend de la vitesse pour fonctionner
        DX=DX2=0
#        Canevas.coords(acc,X-5,Y,X+5,Y+20)

        
def deplacement():        
    global listecoor, DX

    for i in range(len(listecoor)):
        x,y = listecoor[i]
        Canevas.coords(i+4,x,y,x+30,y+20)
    
    
def deplaceboucle():
    global X,Y,DX,Bouton1,X2,DX2,dst_secu,Power_Frein,Y2,listecoor,D,ttt
    
    tourdepiste()
#    distancedesecu()
#    accident()
    deplacement()
    depassement()
    if ttt == True:
        D[-4]=0

    
    # mise à jour toutes les 50 ms
    Mafenetre.after(50,deplaceboucle)
    Bouton1['state'] = 'disabled'
    Bouton1['relief'] = SUNKEN
    return


#-------------------fenetre----------------------




def plus():
    global DX,DX2,D
    D[0]=D[0]+1

def plus2():
    global DX2,DX
    DX2=DX2+2
    
def moins():
    global DX,DX2
    D[0]=D[0]-1

def var():
    global DX,Valeur,DX2
    DX = int(Valeur.get())
    
ttt=False    
def frein():
    global D,ttt
    
    ttt=True  
    
    
Valeur = StringVar()
Valeur.set(10.0)
bouton_bleu4 = Spinbox(Mafenetre,from_=-30,to=30,increment=1,textvariable=Valeur,width=10,command = var)
bouton_bleu4.pack(side = RIGHT,padx=5,pady=5)
Label(Mafenetre,text="Vitesse bleu").pack(side = RIGHT,padx=5,pady=5)

Bouton1 = Button(Mafenetre, text ='GO',width=10 ,command = deplaceboucle)
Bouton1.pack(side = LEFT, padx = 5, pady = 5)

Bouton_bleu5 = Button(Mafenetre, text ='Frein bleu',width=10, command = frein)
Bouton_bleu5.pack(side = LEFT, padx = 5, pady = 5)

Bouton_rouge1 = Button(Mafenetre, text ='+rouge',width=10, command = plus2)
Bouton_rouge1.pack(padx = 5, pady = 5)

Bouton_bleu2 = Button(Mafenetre, text ='+bleu',width=10, command = plus,repeatdelay=500 ,repeatinterval=100)
Bouton_bleu2.pack(padx = 5, pady = 5)

Bouton_bleu3 = Button(Mafenetre, text ='-bleu',width=10, command = moins)
Bouton_bleu3.pack(padx = 5, pady = 5)

Mafenetre.mainloop()

# %%
from tkinter import *
import math,random
import time

LARGEUR = 1500
HAUTEUR = 160

# Création de la fenêtre principale
Mafenetre = Tk()
Mafenetre.title("Animation")

#photo = PhotoImage(file="./Téléchargements/route3.png")


# Création d'un widget Canvas
Canevas = Canvas(Mafenetre,height=HAUTEUR,width=LARGEUR,bg='white')
#Canevas.create_image(0, 0, anchor=NW, image=photo)
Canevas.pack(padx=5,pady=5)


# ------------position initiale au milieu
X = 200
Y = 100
X2 = 10
Y2 = 100

#-----------vitesse initial
v_limite = 6
DX = 5 # 100 pixel/seconde (10m/s ? 36 km/h ?)
DX2 = 6 # 120 pixel/seconde

#----------distance de securiter
dst_secu=50 
dst_depassement=75

#------------puissance des frein( un chiffre apres la virgule max)
Power_Frein=1

#-----------les lignes
fondherbe = Canevas.create_rectangle(0,0,LARGEUR,HAUTEUR,width=1,fill='green4')
fond = Canevas.create_rectangle(0,Y-65,LARGEUR,Y+25,width=1,fill='gray75')
ligne = Canevas.create_line(0,Y+25,LARGEUR,Y+25)
ligne2 = Canevas.create_line(0,Y-5,LARGEUR,Y-5,stipple='gray75')
ligne3 = Canevas.create_line(0,Y-35,LARGEUR,Y-35,stipple='gray75')
ligne4 = Canevas.create_line(0,Y-65,LARGEUR,Y-65)

#-----------couleur des voitures
def randomcouleur():
    couleurde = random.randint(1,370)
    colo = ['gainsboro', 'floral white', 'old lace',
    'linen', 'antique white', 'papaya whip', 'blanched almond', 'bisque', 'peach puff',
    'navajo white', 'lemon chiffon', 'mint cream', 'alice blue', 'lavender',
    'lavender blush', 'misty rose', 'dark slate gray', 'dim gray', 'slate gray',
    'light slate gray', 'gray', 'light grey', 'midnight blue', 'navy', 'cornflower blue', 'dark slate blue',
    'slate blue', 'medium slate blue', 'light slate blue', 'medium blue', 'royal blue',  'blue',
    'dodger blue', 'deep sky blue', 'sky blue', 'light sky blue', 'steel blue', 'light steel blue',
    'light blue', 'powder blue', 'pale turquoise', 'dark turquoise', 'medium turquoise', 'turquoise',
    'cyan', 'light cyan', 'cadet blue', 'medium aquamarine', 'aquamarine', 'dark green', 'dark olive green',
    'dark sea green', 'sea green', 'medium sea green', 'light sea green', 'pale green', 'spring green',
    'lawn green', 'medium spring green', 'green yellow', 'lime green', 'yellow green',
    'forest green', 'olive drab', 'dark khaki', 'khaki', 'pale goldenrod', 'light goldenrod yellow',
    'light yellow', 'yellow', 'gold', 'light goldenrod', 'goldenrod', 'dark goldenrod', 'rosy brown',
    'indian red', 'saddle brown', 'sandy brown',
    'dark salmon', 'salmon', 'light salmon', 'orange', 'dark orange',
    'coral', 'light coral', 'tomato', 'orange red', 'hot pink', 'deep pink', 'pink', 'light pink',
    'pale violet red', 'maroon', 'medium violet red', 'violet red',
    'medium orchid', 'dark orchid', 'dark violet', 'blue violet', 'purple', 'medium purple',
    'thistle', 'snow2', 'snow3',
    'snow4', 'seashell2', 'seashell3', 'seashell4', 'AntiqueWhite1', 'AntiqueWhite2',
    'AntiqueWhite3', 'AntiqueWhite4', 'bisque2', 'bisque3', 'bisque4', 'PeachPuff2',
    'PeachPuff3', 'PeachPuff4', 'NavajoWhite2', 'NavajoWhite3', 'NavajoWhite4',
    'LemonChiffon2', 'LemonChiffon3', 'LemonChiffon4', 'cornsilk2', 'cornsilk3',
    'cornsilk4', 'ivory2', 'ivory3', 'ivory4', 'honeydew2', 'honeydew3', 'honeydew4',
    'LavenderBlush2', 'LavenderBlush3', 'LavenderBlush4', 'MistyRose2', 'MistyRose3',
    'MistyRose4', 'azure2', 'azure3', 'azure4', 'SlateBlue1', 'SlateBlue2', 'SlateBlue3',
    'SlateBlue4', 'RoyalBlue1', 'RoyalBlue2', 'RoyalBlue3', 'RoyalBlue4', 'blue2', 'blue4',
    'DodgerBlue2', 'DodgerBlue3', 'DodgerBlue4', 'SteelBlue1', 'SteelBlue2',
    'SteelBlue3', 'SteelBlue4', 'DeepSkyBlue2', 'DeepSkyBlue3', 'DeepSkyBlue4',
    'SkyBlue1', 'SkyBlue2', 'SkyBlue3', 'SkyBlue4', 'LightSkyBlue1', 'LightSkyBlue2',
    'LightSkyBlue3', 'LightSkyBlue4', 'SlateGray1', 'SlateGray2', 'SlateGray3',
    'SlateGray4', 'LightSteelBlue1', 'LightSteelBlue2', 'LightSteelBlue3',
    'LightSteelBlue4', 'LightBlue1', 'LightBlue2', 'LightBlue3', 'LightBlue4',
    'LightCyan2', 'LightCyan3', 'LightCyan4', 'PaleTurquoise1', 'PaleTurquoise2',
    'PaleTurquoise3', 'PaleTurquoise4', 'CadetBlue1', 'CadetBlue2', 'CadetBlue3',
    'CadetBlue4', 'turquoise1', 'turquoise2', 'turquoise3', 'turquoise4', 'cyan2', 'cyan3',
    'cyan4', 'DarkSlateGray1', 'DarkSlateGray2', 'DarkSlateGray3', 'DarkSlateGray4',
    'aquamarine2', 'aquamarine4', 'DarkSeaGreen1', 'DarkSeaGreen2', 'DarkSeaGreen3',
    'DarkSeaGreen4', 'SeaGreen1', 'SeaGreen2', 'SeaGreen3', 'PaleGreen1', 'PaleGreen2',
    'PaleGreen3', 'PaleGreen4', 'SpringGreen2', 'SpringGreen3', 'SpringGreen4',
    'green2', 'green3', 'green4', 'chartreuse2', 'chartreuse3', 'chartreuse4',
    'OliveDrab1', 'OliveDrab2', 'OliveDrab4', 'DarkOliveGreen1', 'DarkOliveGreen2',
    'DarkOliveGreen3', 'DarkOliveGreen4', 'khaki1', 'khaki2', 'khaki3', 'khaki4',
    'LightGoldenrod1', 'LightGoldenrod2', 'LightGoldenrod3', 'LightGoldenrod4',
    'LightYellow2', 'LightYellow3', 'LightYellow4', 'yellow2', 'yellow3', 'yellow4',
    'gold2', 'gold3', 'gold4', 'goldenrod1', 'goldenrod2', 'goldenrod3', 'goldenrod4',
    'DarkGoldenrod1', 'DarkGoldenrod2', 'DarkGoldenrod3', 'DarkGoldenrod4',
    'RosyBrown1', 'RosyBrown2', 'RosyBrown3', 'RosyBrown4', 'IndianRed1', 'IndianRed2',
    'IndianRed3', 'IndianRed4', 'sienna1', 'sienna2', 'sienna3', 'sienna4', 'burlywood1',
    'burlywood2', 'burlywood3', 'burlywood4', 'wheat1', 'wheat2', 'wheat3', 'wheat4', 'tan1',
    'tan2', 'tan4', 'chocolate1', 'chocolate2', 'chocolate3', 'firebrick1', 'firebrick2',
    'firebrick3', 'firebrick4', 'brown1', 'brown2', 'brown3', 'brown4', 'salmon1', 'salmon2',
    'salmon3', 'salmon4', 'LightSalmon2', 'LightSalmon3', 'LightSalmon4', 'orange2',
    'orange3', 'orange4', 'DarkOrange1', 'DarkOrange2', 'DarkOrange3', 'DarkOrange4',
    'coral1', 'coral2', 'coral3', 'coral4', 'tomato2', 'tomato3', 'tomato4', 'OrangeRed2',
    'OrangeRed3', 'OrangeRed4', 'red2', 'red3', 'red4', 'DeepPink2', 'DeepPink3', 'DeepPink4',
    'HotPink1', 'HotPink2', 'HotPink3', 'HotPink4', 'pink1', 'pink2', 'pink3', 'pink4',
    'LightPink1', 'LightPink2', 'LightPink3', 'LightPink4', 'PaleVioletRed1',
    'PaleVioletRed2', 'PaleVioletRed3', 'PaleVioletRed4', 'maroon1', 'maroon2',
    'maroon3', 'maroon4', 'VioletRed1', 'VioletRed2', 'VioletRed3', 'VioletRed4',
    'magenta2', 'magenta3', 'magenta4', 'orchid1', 'orchid2', 'orchid3', 'orchid4', 'plum1',
    'plum2', 'plum3', 'plum4', 'MediumOrchid1', 'MediumOrchid2', 'MediumOrchid3',
    'MediumOrchid4', 'DarkOrchid1', 'DarkOrchid2', 'DarkOrchid3', 'DarkOrchid4',
    'purple1', 'purple2', 'purple3', 'purple4', 'MediumPurple1', 'MediumPurple2',
    'MediumPurple3', 'MediumPurple4', 'thistle1', 'thistle2', 'thistle3', 'thistle4']
    
    return colo[couleurde]
    
    
    
#-------------- les coordonnes
listecoor = []
D = []
D_O=[]
def lescoor(nombrevoiture):
    global listecoor, D
    
    for i in range(nombrevoiture):
            if i <16:                    #retour a la ligne si trop de voiture
                xx = 100 +i*85
                yy = 100 
                listecoor.append((xx,yy))
            elif i <32:
                xx = 100 +i*85 - 1360
                yy = 100 - 30 
                listecoor.append((xx,yy))
            else :
                xx = 100 +i*85 - 2*1360
                yy = 100 - 2*30 
                listecoor.append((xx,yy))
                
#-------------- la vitesse de chaque voiture
    
    for j in range(nombrevoiture):
        RAM=random.randint(5,6)
        
        lol=random.randint(1,50)   #une chance sur 50 qu'une voiture folle apparaisse
        if lol==1:
            RAM=RAM+2
            
        camion=random.randint(1,10)   #une chance sur 10 qu'un poid lourd apparaisse
        if camion==1:
            RAM=RAM-1
            
        elif camion==2:      #une chance sur 10 qu'un poid lourd apparaisse
            RAM=RAM+1
            
        D.append(RAM)
        D_O.append(RAM)
    print(D_O)
    
#-------------- creation puis affichage des voitures
    
def lesvoitures():
    global listecoor, D,D_O
    listevoiture = []
    for i in range(len(listecoor)):
        x,y = listecoor[i]
        
        if D_O[i]==4:
            i=Canevas.create_rectangle(x,y,x+45,y+20,width=1,fill='gray1')
        elif D_O[i]==7:
            i=Canevas.create_rectangle(x,y,x+20,y+10,width=1,fill='red')
        else:
            i=Canevas.create_rectangle(x,y,x+30,y+20,width=1,fill=randomcouleur())    
    
def affichervoiture():
    global nbrevoiture
    lescoor(int(nbrevoiture.get()))    
    lesvoitures()

#-------------- retour au debut une fois a droite
    
def tourdepiste():
    global listecoor, D
    
    for i in range(len(listecoor)):
        x,y = listecoor[i]
    
        if x > LARGEUR:
            x = -60

        listecoor[i]=x+D[i],y

#--------------gestion des distances de securiter

def distancedesecu():
    global X,Y,DX,Bouton1,X2,DX2,dst_secu,Power_Frein,Y2,listecoor, D, D_O
    for i in range(len(listecoor)):
        xi,yi = listecoor[i]
        b=True
        for j in range(len(listecoor)):
            if i!=j:
                xj,yj = listecoor[j]
                if ((xj-xi)<=70 and (xj-xi)>0) and yi==yj :#yi <= yj and yi >= yj-20:
                    b=False
                    break
        if b:
            if D[i] < D_O[i]: 
                D[i] = D[i]+1
                
            
        else:
            if D[i]-Power_Frein >=0 :
                D[i]=D[i]-Power_Frein
    return
    
#--------------depassement (oui c'est compliquer)
    
def depassement():
    global X,Y,DX,X2,DX2,dst_secu,Y2,listecoor, D
    for i in range(len(listecoor)):
        xi,yi = listecoor[i]
        b=True
        c=True
        for j in range(len(listecoor)):
            if i!=j:
                xj,yj = listecoor[j]
                if (xj-xi)<=80 and (xj-xi)>0 and yi==yj:
                     b=False
                    #break
                    
                if (xi-xj)<=125 and (xi-xj)>85 and (yi+30==100 or yi+60==100) :
                    c=False
                
        if b==False:
            for k in range(len(listecoor)):
                xk,yk = listecoor[k]
                if i!=k:
                    if (xk-xi)<=80 and (xk-xi)>-81 and yi-30==yk:
                        b = True
           
            if b==False:
                if yi-30 >=40:
                    listecoor[i]= xi,yi-30
           
        if c==False:
            for k in range(len(listecoor)):
                xk,yk = listecoor[k]
                if i!=k:
                    if (xk-xi)<=80 and (xk-xi)>-81 and yi+30==yk:
                        c = True
            if c==False:       
                listecoor[i]= xi,yi+30     
            

def accident():
    global X,Y,DX,Bouton1,X2,DX2,dst_secu,Power_Frein,Y2,listecoor, D,D_O
    
    lesaccident=set()
    #accident(rencontre entre deux voiture)
    for i in range(len(listecoor)):
        xi,yi = listecoor[i]
        for j in range(len(listecoor)):
            if i!=j:
                xj,yj = listecoor[j]
                if ((xj-xi)<=0 and (xj-xi)>-30) and yi==yj :
                    D[i]=0
                    D_O[i]=0
                    D[j]=0
                    D_O[j]=0
                    lesaccident.add(i)
                    lesaccident.add(j)

        
def deplacement():        
    global listecoor, D,D_O

    for i in range(len(listecoor)):
        x,y = listecoor[i]
        if D_O[i]==4:
            Canevas.coords(i+7,x,y,x+45,y+20)
        elif D_O[i]==7:
            Canevas.coords(i+7,x,y,x+20,y+10)
        else:
            Canevas.coords(i+7,x,y,x+30,y+20)
    
def lancement():
    affichervoiture()
    deplaceboucle()
    
    
def deplaceboucle():
    global X,Y,DX,Bouton1,X2,DX2,dst_secu,Power_Frein,Y2,listecoor,D,ttt,lapanne
    
    tourdepiste()
    distancedesecu()
#    accident()
    deplacement()
    depassement()
    if ttt == True:
        D[lapanne]=0
    moyennevitesse()
    
    # mise à jour toutes les 50 ms
    Mafenetre.after(50,deplaceboucle)
    Bouton1['state'] = 'disabled'
    Bouton1['relief'] = SUNKEN
    return


#-------------------fenetre----------------------




def plus():
    global DX,DX2,D
    D[0]=D[0]+1

def plus2():
    global DX2,DX
    DX2=DX2+2
    
def moins():
    global DX,DX2
    D[0]=D[0]-1

def var():
    global DX,Valeur,DX2
    DX = int(Valeur.get())
    
ttt=False    
def frein():
    global D,ttt,lapanne
    lapanne=(random.randint(0,len(listecoor)-1))
    ttt=True  
    

def moyennevitesse():
    global D,moyenneV
    s=0
    n=0
    for i in D:
        s=s+i
    moyenneV.set(str(round((s/len(D)*80/5),2)))
    
#-------------- les boutons
moyenneV = StringVar()
LabelResultat = Label(Mafenetre, textvariable = moyenneV, width=5 , bg ='white')
LabelResultat.pack(side = RIGHT, padx = 5, pady = 5)

Label2 = Label(Mafenetre, text = 'Vitesse moyenne instantanée:')
Label2.pack(side = RIGHT, padx = 5, pady = 5)

#Valeur = StringVar()
#Valeur.set(10.0)
#bouton_bleu4 = Spinbox(Mafenetre,from_=-30,to=30,increment=1,textvariable=Valeur,width=10,command = var)
#bouton_bleu4.pack(side = RIGHT,padx=5,pady=5)
#Label(Mafenetre,text="Vitesse bleu").pack(side = RIGHT,padx=5,pady=5)

Label1 = Label(Mafenetre, text = 'Nombre de voitures :')
Label1.pack(side = LEFT, padx = 5, pady = 5)

nbrevoiture= StringVar()
Champ = Entry(Mafenetre, textvariable= nbrevoiture)
Champ.focus_set()
Champ.pack(side = LEFT, padx = 5, pady = 5)

Bouton1 = Button(Mafenetre, text ='GO',width=10 ,command = lancement)
Bouton1.pack(side = LEFT, padx = 5, pady = 5)

Bouton_bleu5 = Button(Mafenetre, text ='Panne',width=10, command = frein)
Bouton_bleu5.pack( padx = 5, pady = 5)

Bouton_bleu2 = Button(Mafenetre, text ='+bleu',width=10, command = plus,repeatdelay=500 ,repeatinterval=100)
Bouton_bleu2.pack(padx = 5, pady = 5)

Bouton_bleu3 = Button(Mafenetre, text ='-bleu',width=10, command = moins)
Bouton_bleu3.pack(padx = 5, pady = 5)

Mafenetre.mainloop()
# Out:
# [5, 6, 5, 5, 5, 5, 5, 5, 6, 6, 6, 5, 6, 7, 6, 5, 6, 6, 6, 6, 6, 6, 6, 5]
